# %% [markdown]
# ___
#
# <a href='https://mainacademy.ua/'> <img src='https://mainacademy.ua/wp-content/uploads/2019/03/logo-main.png' alt = 'Хмм, щось з інтернетом'/></a>
# ___
#
# # Module 5: Data analysis with NumPy and Pandas

# %% [markdown]
# ## Lab work 5.2

# %% [markdown]
# #### Мета:
#
# * навчитися працювати із бібліотекою Pandas в Python.

# %% [markdown]
# ### Завдання:

# %%
import pandas as pd

# %% [markdown]
# Вивести версію та конфігурацію бібліотеки:

# %%
#pd.__version__
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : 2cb96529396d93b46abab7bbc73a208e708c642e
# python           : 3.8.8.final.0
# python-bits      : 64
# OS               : Windows
# OS-release       : 10
# Version          : 10.0.19041
# machine          : AMD64
# processor        : AMD64 Family 16 Model 4 Stepping 3, AuthenticAMD
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : English_United States.1251
#
# pandas           : 1.2.4
# numpy            : 1.20.1
# pytz             : 2021.1
# dateutil         : 2.8.1
# pip              : 21.0.1
# setuptools       : 52.0.0.post20210125
# Cython           : 0.29.23
# pytest           : 6.2.3
# hypothesis       : None
# sphinx           : 4.0.1
# blosc            : None
# feather          : None
# xlsxwriter       : 1.3.8
# lxml.etree       : 4.6.3
# html5lib         : 1.1
# pymysql          : None
# psycopg2         : None
# jinja2           : 2.11.3
# IPython          : 7.22.0
# pandas_datareader: None
# bs4              : 4.9.3
# bottleneck       : 1.3.2
# fsspec           : 0.9.0
# fastparquet      : None
# gcsfs            : None
# matplotlib       : 3.3.4
# numexpr          : 2.7.3
# odfpy            : None
# openpyxl         : 3.0.7
# pandas_gbq       : None
# pyarrow          : None
# pyxlsb           : None
# s3fs             : None
# scipy            : 1.6.2
# sqlalchemy       : 1.4.7
# tables           : 3.6.1
# tabulate         : None
# xarray           : None
# xlrd             : 2.0.1
# xlwt             : 1.3.0
# numba            : 0.53.1

# %%
df = pd.read_csv('Ecommerce Purchases')

# %% [markdown]
# Скільки рядків і стовпців в наборі даних:

# %%
df.shape
# Out:
# (10000, 14)

# %% [markdown]
# Перевірити, чи в наборі даних містяться порожні значення:

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# Яка середня ціна закупки (Purchase Price):

# %%
df['Purchase Price'].mean()
# Out:
# 50.34730200000025

# %% [markdown]
# Скільки людей користуються англійською мовою "en" на веб-сайті:

# %%
(df.Language == 'en').sum()
# Out:
# 1098

# %% [markdown]
# Скільки людей має посаду «Lawyer»?

# %%
(df.Job == 'Lawyer').sum()
# Out:
# 30

# %% [markdown]
# Скільки людей зробило покупку вранці та скільки людей зробило покупку після обіду?

# %%
print('Кількість людей, що купили зранку =', (df['AM or PM'] == 'AM').sum())
print('Кількість людей, що купили після обіду =', (df['AM or PM'] == 'PM').sum())
# Out:
# Кількість людей, що купили зранку = 4932
# Кількість людей, що купили після обіду = 5068

# %% [markdown]
# Які 5 найпоширеніших назв вакансій?

# %%
df['Job'].value_counts()[:5].sort_values(ascending=False)
# Out:
# Interior and spatial designer        31
# Lawyer                               30
# Social researcher                    28
# Research officer, political party    27
# Purchasing manager                   27
# Name: Job, dtype: int64

# %% [markdown]
# Хтось здійснив покупку, яка надійшла від Lot: "90 Wt", та якою була ціна придбання для цієї транзакції?

# %%
df[df['Lot'] == '90 WT'][['Company', 'Purchase Price']]
# Out:
#         Company  Purchase Price
# 513  Bright PLC            75.1

# %% [markdown]
# Яка електронна адреса особи з таким номером кредитної картки: 4926535242672853 ?

# %%
df[df['Credit Card'] == 4926535242672853]['Email']
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: object

# %% [markdown]
# Скільки людей використовує American Express  і здійснили покупку на суму понад 100 доларів?

# %%
df[(df['CC Provider'] == 'American Express') & (df['Purchase Price'] > 90)].count()[1]
# Out:
# 86

# %% [markdown]
# Скільки людей мають кредитну картку, термін дії якої закінчується в 2025 році?

# %%
df['CC Exp Date'].map(lambda i: '25' in i).sum()
# Out:
# 1033

# %% [markdown]
# Які найкращі 5 найпопулярніших постачальників / хостів електронної пошти (наприклад, gmail.com, yahoo.com тощо ...).

# %%
df['Email'].map(lambda i: i.split('@')[1]).value_counts()[:5]
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64

# %% [markdown]
# Виведіть зведену таблицю по браузерах(Browser Info), посаді(Job), та кількості транзакцій :

# %%
df.pivot_table(index = 'Job', columns ='Browser Info', aggfunc = {'Credit Card': 'value_counts', })
# Out:
#                                                                                                                                                           Credit Card  \
# Browser Info                        Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_0 rv:2.0; sl-SI) AppleWebKit/533.25.6 (KHTML, like Gecko) Version/4.0 Safari/533.25.6
# Job                Credit Card
# Academic librarian 4197434016663                                                   NaN
#                    30435953333392                                                  NaN
#                    3088397087539796                                                NaN
#                    4036104378992887                                                NaN
#                    4105681690623817                                                NaN
# ...                                                                                ...
# Youth worker       3158764724172148                                                NaN
#                    3528256757120253                                                NaN
#                    4346670059077870                                                NaN
#                    4591758934972928                                                NaN
#                    6011819452653352                                                NaN
#
#                                                                                                                                                                        \
# Browser Info                        Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_0 rv:4.0; en-US) AppleWebKit/535.34.7 (KHTML, like Gecko) Version/5.0 Safari/535.34.7
# Job                Credit Card
# Academic librarian 4197434016663                                                   NaN
#                    30435953333392                                                  NaN
#                    3088397087539796                                                NaN
#                    4036104378992887                                                NaN
#                    4105681690623817                                                NaN
# ...                                                                                ...
# Youth worker       3158764724172148                                                NaN
#                    3528256757120253                                                NaN
#                    4346670059077870                                                NaN
#                    4591758934972928                                                NaN
#                    6011819452653352                                                NaN
#
#                                                                                                                                                                          \
# Browser Info                        Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_0 rv:5.0; sl-SI) AppleWebKit/532.10.4 (KHTML, like Gecko) Version/5.0.2 Safari/532.10.4
# Job                Credit Card
# Academic librarian 4197434016663                                                   NaN
#                    30435953333392                                                  NaN
#                    3088397087539796                                                NaN
#                    4036104378992887                                                NaN
#                    4105681690623817                                                NaN
# ...                                                                                ...
# Youth worker       3158764724172148                                                NaN
#                    3528256757120253                                                NaN
#                    4346670059077870                                                NaN
#                    4591758934972928                                                NaN
#                    6011819452653352                                                NaN
#
#                                                                                                                                                                        \
# Browser Info                        Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_0 rv:6.0; en-US) AppleWebKit/533.45.4 (KHTML, like Gecko) Version/4.1 Safari/533.45.4
# Job                Credit Card
# Academic librarian 4197434016663                                                   NaN
#                    30435953333392                                                  NaN
#                    3088397087539796                                                NaN
#                    4036104378992887                                                NaN
#                    4105681690623817                                                NaN
# ...                                                                                ...
# Youth worker       3158764724172148                                                NaN
#                    3528256757120253                                                NaN
#                    4346670059077870                                                NaN
#                    4591758934972928                                                NaN
#                    6011819452653352                                                NaN
#
#                                                                                                                                                        \
# Browser Info                        Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_0) AppleWebKit/5321 (KHTML, like Gecko) Chrome/14.0.824.0 Safari/5321
# Job                Credit Card
# Academic librarian 4197434016663                                                   NaN
#                    30435953333392                                                  NaN
#                    3088397087539796                                                NaN
#                    4036104378992887                                                NaN
#                    4105681690623817                                                NaN
# ...                                                                                ...
# Youth worker       3158764724172148                                                NaN
#                    3528256757120253                                                NaN
#                    4346670059077870                                                NaN
#                    4591758934972928                                                NaN
#                    6011819452653352                                                NaN
#
#                                                                                                                                                        \
# Browser Info                        Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_0) AppleWebKit/5342 (KHTML, like Gecko) Chrome/15.0.804.0 Safari/5342
# Job                Credit Card
# Academic librarian 4197434016663                                                   NaN
#                    30435953333392                                                  NaN
#                    3088397087539796                                                NaN
#                    4036104378992887                                                NaN
#                    4105681690623817                                                NaN
# ...                                                                                ...
# Youth worker       3158764724172148                                                NaN
#                    3528256757120253                                                NaN
#                    4346670059077870                                                NaN
#                    4591758934972928                                                NaN
#                    6011819452653352                                                NaN
#
#                                                                                                                                                        \
# Browser Info                        Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_0) AppleWebKit/5351 (KHTML, like Gecko) Chrome/15.0.826.0 Safari/5351
# Job                Credit Card
# Academic librarian 4197434016663                                                   NaN
#                    30435953333392                                                  NaN
#                    3088397087539796                                                NaN
#                    4036104378992887                                                NaN
#                    4105681690623817                                                NaN
# ...                                                                                ...
# Youth worker       3158764724172148                                                NaN
#                    3528256757120253                                                NaN
#                    4346670059077870                                                NaN
#                    4591758934972928                                                NaN
#                    6011819452653352                                                NaN
#
#                                                                                                                                         \
# Browser Info                        Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_0; rv:1.9.3.20) Gecko/2012-09-04 22:53:51 Firefox/15.0
# Job                Credit Card
# Academic librarian 4197434016663                                                   NaN
#                    30435953333392                                                  NaN
#                    3088397087539796                                                NaN
#                    4036104378992887                                                NaN
#                    4105681690623817                                                NaN
# ...                                                                                ...
# Youth worker       3158764724172148                                                NaN
#                    3528256757120253                                                NaN
#                    4346670059077870                                                NaN
#                    4591758934972928                                                NaN
#                    6011819452653352                                                NaN
#
#                                                                                                                                           \
# Browser Info                        Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_0; rv:1.9.3.20) Gecko/2014-03-25 20:43:00 Firefox/3.6.14
# Job                Credit Card
# Academic librarian 4197434016663                                                   NaN
#                    30435953333392                                                  NaN
#                    3088397087539796                                                NaN
#                    4036104378992887                                                NaN
#                    4105681690623817                                                NaN
# ...                                                                                ...
# Youth worker       3158764724172148                                                NaN
#                    3528256757120253                                                NaN
#                    4346670059077870                                                NaN
#                    4591758934972928                                                NaN
#                    6011819452653352                                                NaN
#
#                                                                                                                                         \
# Browser Info                        Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_0; rv:1.9.4.20) Gecko/2011-11-29 18:18:33 Firefox/11.0
# Job                Credit Card
# Academic librarian 4197434016663                                                   NaN
#                    30435953333392                                                  NaN
#                    3088397087539796                                                NaN
#                    4036104378992887                                                NaN
#                    4105681690623817                                                NaN
# ...                                                                                ...
# Youth worker       3158764724172148                                                NaN
#                    3528256757120253                                                NaN
#                    4346670059077870                                                NaN
#                    4591758934972928                                                NaN
#                    6011819452653352                                                NaN
#
#                                      ...  \
# Browser Info                         ...
# Job                Credit Card       ...
# Academic librarian 4197434016663     ...
#                    30435953333392    ...
#                    3088397087539796  ...
#                    4036104378992887  ...
#                    4105681690623817  ...
# ...                                  ...
# Youth worker       3158764724172148  ...
#                    3528256757120253  ...
#                    4346670059077870  ...
#                    4591758934972928  ...
#                    6011819452653352  ...
#
#                                                                                                      \
# Browser Info                        Opera/9.99.(Windows NT 6.2; en-US) Presto/2.9.162 Version/10.00
# Job                Credit Card
# Academic librarian 4197434016663                                                   NaN
#                    30435953333392                                                  NaN
#                    3088397087539796                                                NaN
#                    4036104378992887                                                NaN
#                    4105681690623817                                                NaN
# ...                                                                                ...
# Youth worker       3158764724172148                                                NaN
#                    3528256757120253                                                NaN
#                    4346670059077870                                                NaN
#                    4591758934972928                                                NaN
#                    6011819452653352                                                NaN
#
#                                                                                                      \
# Browser Info                        Opera/9.99.(Windows NT 6.2; it-IT) Presto/2.9.163 Version/10.00
# Job                Credit Card
# Academic librarian 4197434016663                                                   NaN
#                    30435953333392                                                  NaN
#                    3088397087539796                                                NaN
#                    4036104378992887                                                NaN
#                    4105681690623817                                                NaN
# ...                                                                                ...
# Youth worker       3158764724172148                                                NaN
#                    3528256757120253                                                NaN
#                    4346670059077870                                                NaN
#                    4591758934972928                                                NaN
#                    6011819452653352                                                NaN
#
#                                                                                                       \
# Browser Info                        Opera/9.99.(X11; Linux i686; en-US) Presto/2.9.171 Version/12.00
# Job                Credit Card
# Academic librarian 4197434016663                                                   NaN
#                    30435953333392                                                  NaN
#                    3088397087539796                                                NaN
#                    4036104378992887                                                NaN
#                    4105681690623817                                                NaN
# ...                                                                                ...
# Youth worker       3158764724172148                                                NaN
#                    3528256757120253                                                NaN
#                    4346670059077870                                                NaN
#                    4591758934972928                                                NaN
#                    6011819452653352                                                NaN
#
#                                                                                                       \
# Browser Info                        Opera/9.99.(X11; Linux i686; it-IT) Presto/2.9.177 Version/12.00
# Job                Credit Card
# Academic librarian 4197434016663                                                   NaN
#                    30435953333392                                                  NaN
#                    3088397087539796                                                NaN
#                    4036104378992887                                                NaN
#                    4105681690623817                                                NaN
# ...                                                                                ...
# Youth worker       3158764724172148                                                NaN
#                    3528256757120253                                                NaN
#                    4346670059077870                                                NaN
#                    4591758934972928                                                NaN
#                    6011819452653352                                                NaN
#
#                                                                                                       \
# Browser Info                        Opera/9.99.(X11; Linux i686; it-IT) Presto/2.9.190 Version/12.00
# Job                Credit Card
# Academic librarian 4197434016663                                                   NaN
#                    30435953333392                                                  NaN
#                    3088397087539796                                                NaN
#                    4036104378992887                                                NaN
#                    4105681690623817                                                NaN
# ...                                                                                ...
# Youth worker       3158764724172148                                                NaN
#                    3528256757120253                                                NaN
#                    4346670059077870                                                NaN
#                    4591758934972928                                                NaN
#                    6011819452653352                                                NaN
#
#                                                                                                       \
# Browser Info                        Opera/9.99.(X11; Linux i686; sl-SI) Presto/2.9.186 Version/12.00
# Job                Credit Card
# Academic librarian 4197434016663                                                   NaN
#                    30435953333392                                                  NaN
#                    3088397087539796                                                NaN
#                    4036104378992887                                                NaN
#                    4105681690623817                                                NaN
# ...                                                                                ...
# Youth worker       3158764724172148                                                NaN
#                    3528256757120253                                                NaN
#                    4346670059077870                                                NaN
#                    4591758934972928                                                NaN
#                    6011819452653352                                                NaN
#
#                                                                                                         \
# Browser Info                        Opera/9.99.(X11; Linux x86_64; en-US) Presto/2.9.172 Version/12.00
# Job                Credit Card
# Academic librarian 4197434016663                                                   NaN
#                    30435953333392                                                  NaN
#                    3088397087539796                                                NaN
#                    4036104378992887                                                NaN
#                    4105681690623817                                                NaN
# ...                                                                                ...
# Youth worker       3158764724172148                                                NaN
#                    3528256757120253                                                NaN
#                    4346670059077870                                                NaN
#                    4591758934972928                                                NaN
#                    6011819452653352                                                NaN
#
#                                                                                                         \
# Browser Info                        Opera/9.99.(X11; Linux x86_64; en-US) Presto/2.9.176 Version/10.00
# Job                Credit Card
# Academic librarian 4197434016663                                                   NaN
#                    30435953333392                                                  NaN
#                    3088397087539796                                                NaN
#                    4036104378992887                                                NaN
#                    4105681690623817                                                NaN
# ...                                                                                ...
# Youth worker       3158764724172148                                                NaN
#                    3528256757120253                                                NaN
#                    4346670059077870                                                NaN
#                    4591758934972928                                                NaN
#                    6011819452653352                                                NaN
#
#                                                                                                         \
# Browser Info                        Opera/9.99.(X11; Linux x86_64; it-IT) Presto/2.9.164 Version/10.00
# Job                Credit Card
# Academic librarian 4197434016663                                                   NaN
#                    30435953333392                                                  NaN
#                    3088397087539796                                                NaN
#                    4036104378992887                                                NaN
#                    4105681690623817                                                NaN
# ...                                                                                ...
# Youth worker       3158764724172148                                                NaN
#                    3528256757120253                                                NaN
#                    4346670059077870                                                NaN
#                    4591758934972928                                                NaN
#                    6011819452653352                                                NaN
#
#
# Browser Info                        Opera/9.99.(X11; Linux x86_64; it-IT) Presto/2.9.190 Version/11.00
# Job                Credit Card
# Academic librarian 4197434016663                                                   NaN
#                    30435953333392                                                  NaN
#                    3088397087539796                                                NaN
#                    4036104378992887                                                NaN
#                    4105681690623817                                                NaN
# ...                                                                                ...
# Youth worker       3158764724172148                                                NaN
#                    3528256757120253                                                NaN
#                    4346670059077870                                                NaN
#                    4591758934972928                                                NaN
#                    6011819452653352                                                NaN
#
# [10000 rows x 8287 columns]

# %% [markdown]
# Створіть нову колонку "Actual price", яка утворюється із "Purchase Price" та націнки за принципом:
# - якщо "Purchase Price" > 50, націнка 20%
# - якщо "Purchase Price" > 100, націнка 10%
# - в інших випадках націнка 30%

# %%
def act_price(price):
    if price < 50:
        return price*1.3
    elif price < 90:
        return price*1.2
    else:
        return price*1.1
df['Actual price'] = df['Purchase Price'].map(act_price)
df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 0     Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1     Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2     Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4     Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
# ...                                                 ...
# 9995  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/5352 ...
# 9996  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 9997  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_7...
# 9998  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_8;...
# 9999  Mozilla/5.0 (X11; Linux i686; rv:1.9.5.20) Gec...
#
#                               Company       Credit Card CC Exp Date  \
# 0                     Martinez-Herman  6011929061123406       02/20
# 1     Fletcher, Richards and Whitaker  3337758169645356       11/18
# 2          Simpson, Williams and Pham      675957666125       08/19
# 3     Williams, Marshall and Buchanan  6011578504430710       02/24
# 4           Brown, Watson and Andrews  6011456623207998       10/25
# ...                               ...               ...         ...
# 9995                    Randall-Sloan   342945015358701       03/22
# 9996         Hale, Collins and Wilson   210033169205009       07/25
# 9997                     Anderson Ltd  6011539787356311       05/21
# 9998                         Cook Inc   180003348082930       11/17
# 9999                       Greene Inc  4139972901927273       02/19
#
#       CC Security Code                  CC Provider  \
# 0                  900                 JCB 16 digit
# 1                  561                   Mastercard
# 2                  699                 JCB 16 digit
# 3                  384                     Discover
# 4                  678  Diners Club / Carte Blanche
# ...                ...                          ...
# 9995               838                 JCB 15 digit
# 9996               207                 JCB 16 digit
# 9997                 1                VISA 16 digit
# 9998               987             American Express
# 9999               302                 JCB 15 digit
#
#                                Email                                     Job  \
# 0                  pdunlap@yahoo.com  Scientist, product/process development
# 1                 anthony41@reed.com                       Drilling engineer
# 2     amymiller@morales-harrison.com                Customer service manager
# 3        brent16@olson-robinson.info                       Drilling engineer
# 4        christopherwright@gmail.com                             Fine artist
# ...                              ...                                     ...
# 9995          iscott@wade-garner.com                              Printmaker
# 9996              mary85@hotmail.com                         Energy engineer
# 9997               tyler16@gmail.com                      Veterinary surgeon
# 9998         elizabethmoore@reid.net                Local government officer
# 9999           rachelford@vaughn.com                  Embryologist, clinical
#
#            IP Address Language  Purchase Price  Actual price
# 0     149.146.147.205       el           98.14       107.954
# 1        15.160.41.51       fr           70.73        84.876
# 2      132.207.160.22       de            0.95         1.235
# 3        30.250.74.19       es           78.04        93.648
# 4        24.140.33.94       es           77.82        93.384
# ...               ...      ...             ...           ...
# 9995    29.73.197.114       it           82.21        98.652
# 9996   121.133.168.51       pt           25.63        33.319
# 9997    156.210.0.254       el           83.98       100.776
# 9998     55.78.26.143       es           38.84        50.492
# 9999  176.119.198.199       el           67.59        81.108
#
# [10000 rows x 15 columns]

# %% [markdown]
# Зробіть рангування набору даних по "Language" та "Actual price" в порядку спадання ціни.
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rank.html

# %%
df_rang = df[['Language', 'Actual price']].rank()
df_rang['Actual price'].sort_values(ascending = False)
# Out:
# 2092    9999.5
# 7807    9999.5
# 9856    9998.0
# 7604    9997.0
# 3844    9996.0
#          ...
# 2783       4.5
# 8656       4.5
# 6863       3.0
# 2876       1.5
# 5487       1.5
# Name: Actual price, Length: 10000, dtype: float64

# %% [markdown]
# Колонку "Language" (категоріальна змінна) "закодуйте", тобто утворити індикаторні колоник. В наборі не повинна залишитися колонка "Language".
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rank.html

# %%
df['Language'] = df['Language'].astype("category")
df['encoded_lg'] = df['Language'].cat.codes
df.drop(columns = 'Language')
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 0     Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1     Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2     Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4     Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
# ...                                                 ...
# 9995  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/5352 ...
# 9996  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 9997  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_7...
# 9998  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_8;...
# 9999  Mozilla/5.0 (X11; Linux i686; rv:1.9.5.20) Gec...
#
#                               Company       Credit Card CC Exp Date  \
# 0                     Martinez-Herman  6011929061123406       02/20
# 1     Fletcher, Richards and Whitaker  3337758169645356       11/18
# 2          Simpson, Williams and Pham      675957666125       08/19
# 3     Williams, Marshall and Buchanan  6011578504430710       02/24
# 4           Brown, Watson and Andrews  6011456623207998       10/25
# ...                               ...               ...         ...
# 9995                    Randall-Sloan   342945015358701       03/22
# 9996         Hale, Collins and Wilson   210033169205009       07/25
# 9997                     Anderson Ltd  6011539787356311       05/21
# 9998                         Cook Inc   180003348082930       11/17
# 9999                       Greene Inc  4139972901927273       02/19
#
#       CC Security Code                  CC Provider  \
# 0                  900                 JCB 16 digit
# 1                  561                   Mastercard
# 2                  699                 JCB 16 digit
# 3                  384                     Discover
# 4                  678  Diners Club / Carte Blanche
# ...                ...                          ...
# 9995               838                 JCB 15 digit
# 9996               207                 JCB 16 digit
# 9997                 1                VISA 16 digit
# 9998               987             American Express
# 9999               302                 JCB 15 digit
#
#                                Email                                     Job  \
# 0                  pdunlap@yahoo.com  Scientist, product/process development
# 1                 anthony41@reed.com                       Drilling engineer
# 2     amymiller@morales-harrison.com                Customer service manager
# 3        brent16@olson-robinson.info                       Drilling engineer
# 4        christopherwright@gmail.com                             Fine artist
# ...                              ...                                     ...
# 9995          iscott@wade-garner.com                              Printmaker
# 9996              mary85@hotmail.com                         Energy engineer
# 9997               tyler16@gmail.com                      Veterinary surgeon
# 9998         elizabethmoore@reid.net                Local government officer
# 9999           rachelford@vaughn.com                  Embryologist, clinical
#
#            IP Address  Purchase Price  Actual price  encoded_lg
# 0     149.146.147.205           98.14       107.954           1
# 1        15.160.41.51           70.73        84.876           4
# 2      132.207.160.22            0.95         1.235           0
# 3        30.250.74.19           78.04        93.648           3
# 4        24.140.33.94           77.82        93.384           3
# ...               ...             ...           ...         ...
# 9995    29.73.197.114           82.21        98.652           5
# 9996   121.133.168.51           25.63        33.319           6
# 9997    156.210.0.254           83.98       100.776           1
# 9998     55.78.26.143           38.84        50.492           3
# 9999  176.119.198.199           67.59        81.108           1
#
# [10000 rows x 15 columns]

# %% [markdown]
# Кінцевий набір даних збережіть у файл з розширенням csv.

# %%
df_fin = df.drop(columns = 'Language')
df_fin.to_csv('lab 5.2.csv')
